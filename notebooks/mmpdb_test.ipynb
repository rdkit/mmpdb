# %%
import pandas as pd
from rdkit import Chem,rdBase
from rdkit.Chem import PandasTools
import sqlite3

# %%
con = sqlite3.connect("/home/oriol/dev/mmpdb/tests2/test_data2.mmpdb")
#con = sqlite3.connect("/home/oriol/dev/mmpdb/drugs/drugDB.mmpdb")

cur = con.cursor()

# The result of a "cursor.execute" can be iterated over by row
dfmols = pd.read_sql_query("SELECT * from compound", con)
dftrans = pd.read_sql_query("SELECT * from mols_transformation", con)

# Be sure to close the connection
con.close()

# %%
#PandasTools.AddMoleculeColumnToFrame(dfmols,smilesCol='input_smiles',molCol='input_mol',includeFingerprints=False)
PandasTools.AddMoleculeColumnToFrame(dfmols,smilesCol='clean_smiles',molCol='clean_mol',includeFingerprints=False)

# %%
#columns = ['input_smiles', 'clean_smiles']
#dfmols.drop(columns, inplace=True, axis=1)
dfmols
# Out:
#    id           public_id   input_smiles     clean_smiles  clean_num_heavies                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 0   0  o-phenylenediamine     Nc1ccccc1N       Nc1ccccc1N                  8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>
# 1   1       2-aminophenol     Oc1ccccc1N       Nc1ccccc1O                  8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>
# 2   2              amidol  Nc1cc(O)ccc1N    Nc1ccc(O)cc1N                  9  <img src="data:image/png;base64,..." alt="Mol"/>
# 3   3         phenylamine      Nc1ccccc1        Nc1ccccc1                  7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>
# 4   4       cyclopentanol       C1CCCC1N         NC1CCCC1                  6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <img src="data:image/png;base64,..." alt="Mol"/>
# 5   5              phenol      Oc1ccccc1        Oc1ccccc1                  7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>
# 6   6            catechol     Oc1ccccc1O       Oc1ccccc1O                  8                                                                                                                                                                                                                                                                                                                                                                                                                                                      <img src="data:image/png;base64,..." alt="Mol"/>
# 7   7      2-chlorophenol    Oc1ccccc1Cl      Oc1ccccc1Cl                  8                                                                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>
# 8   8       hydroxyquinol  Oc1cc(O)ccc1O  Oc1ccc(O)c(O)c1                  9                                                                                                                                                                                      <img src="data:image/png;base64,..." alt="Mol"/>

# %%
PandasTools.AddMoleculeColumnToFrame(dftrans,smilesCol='smiles_from',molCol='molecule_from',includeFingerprints=False)
PandasTools.AddMoleculeColumnToFrame(dftrans,smilesCol='smiles_to',molCol='molecule_to',includeFingerprints=False)
PandasTools.AddMoleculeColumnToFrame(dftrans,smilesCol='smirks_from',molCol='smk_from',includeFingerprints=False)
PandasTools.AddMoleculeColumnToFrame(dftrans,smilesCol='smirks_to',molCol='smk_to',includeFingerprints=False)
PandasTools.AddMoleculeColumnToFrame(dftrans,smilesCol='smiles_constant',molCol='constant',includeFingerprints=False)

# %%
dfmerged=dfmols.merge(dftrans, left_on='clean_smiles', right_on='smiles_from', how='inner')

# %%
dff=dftrans.query('id in [2,3]')
dff.sort_values('id')
# Out:
#       smiles_from   smiles_to        smirks_from       smirks_to smiles_constant  id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 15  Nc1cc(O)ccc1N  Oc1ccccc1N  [*:1]c1ccc(O)cc1N  [*:1]c1ccccc1O          [*:1]N   2  <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>
# 23      Nc1ccccc1  Oc1ccccc1N      [*:1]c1ccccc1  [*:1]c1ccccc1O          [*:1]N   3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 48      Oc1ccccc1  Oc1ccccc1O      [*:1]c1ccccc1  [*:1]c1ccccc1O          [*:1]O   3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>  <img src="data:image/png;base64,..." alt="Mol"/>                      <img src="data:image/png;base64,..." alt="Mol"/>

# %%
dfmols.to_csv('/home/oriol/dev/mmpdb/tests2/test_data.mols.csv')
dftrans.to_csv('/home/oriol/dev/mmpdb/tests2/test_data.trans.csv')
dfmerged.to_csv('/home/oriol/dev/mmpdb/tests2/test_data.merged.csv')

# %%
out_mols_pd=pd.read_csv('/home/oriol/dev/mmpdb/tests2/output2.smi',sep='\t')

# %%
PandasTools.AddMoleculeColumnToFrame(out_mols_pd,smilesCol='SMILES',molCol='mol',includeFingerprints=False)

# %%
out_mols_pd
# Out:
#    ID       SMILES                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 0   1   Nc1cccnc1O                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>
# 1   2   Nc1ncccc1O                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <img src="data:image/png;base64,..." alt="Mol"/>
# 2   3    Oc1ccccn1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <img src="data:image/png;base64,..." alt="Mol"/>
# 3   4    Oc1cccnc1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <img src="data:image/png;base64,..." alt="Mol"/>
# 4   5  Oc1cccnc1Cl  <img src="data:image/png;base64,..." alt="Mol"/>
# 5   6  Oc1ncccc1Cl                                                                                                                                                                                      <img src="data:image/png;base64,..." alt="Mol"/>

# %%
from rdkit.Chem import *
m=Chem.MolFromSmiles('Oc1cccnc1O')
Draw.MolToImage(m)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F9277CF6D30>
